# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!
import os
from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI(base_url="https://openrouter.ai/api/v1", api_key=os.getenv("OPENROUTER_API_KEY"))

# %%
reader = PdfReader("me/resume.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Mark  Vasilev  Data  Engineer
# Telegram:  @Mark_Muffin  Cell/  WhatsApp:  +7  (910)  420-55-81  E-mail:  marok12@yandex.ru Tbilisi,  Georgia
#  Profile    Data  Engineer  with  seven  years  of  experience,  including  three  years  in  a  managerial  position
# and
#
# team
#
# leadership.
#
# Extensive
#
# experience
#
# in
#
# designing
#
# and
#
# maintaining
#
# various
#
# ETL
#
# pipelines,
#
# optimizing
#
# data
#
# extraction
#
# processes,
#
# working
#
# with
#
# Data
#
# Quality,
#
# and
#
# handling
#
# large-scale
#
# data.
#
# Successfully
#
# deployed
#
# Data
#
# Science
#
# projects,
#
# including
#
# ML
#
# and
#
# LLM
#
# models,
#
# into
#
# production
#
# and
#
# ensured
#
# their
#
# ability
#
# to
#
# process
#
# large
#
# volumes
#
# of
#
# data
#
# on
#
# a
#
# daily
#
# basis.
#
# Expertise
#
# in
#
# distributed
#
# data
#
# storage
#
# systems
#
# and
#
# ensuring
#
# high
#
# code
#
# quality.
#
# Strong
#
# experience
#
# in
#
# establishing
#
# and
#
# structuring
#
# team
#
# workflows.
#
# Proven
#
# ability
#
# to
#
# communicate
#
# with
#
# customers,
#
# gather
#
# business
#
# requirements,
#
# and
#
# defend
#
# technical
#
# decisions
#
# in
#
# front
#
# of
#
# stakeholders.
#
# Experienced
#
# in
#
# working
#
# within
#
# multicultural
#
# and
#
# cross-functional
#
# teams.
#
# Work  Experience    Team  Lead  —  Semrush  (06/2022  –  Present)
# ●  Led  a  team  of  9  engineers  in  building  a  reliable  and  efficient  data  source  for  product
# teams,
#
# enabling
#
# them
#
# to
#
# develop
#
# their
#
# products
#
# based
#
# on
#
# high-quality
#
# data.
#  ●  Collaborated  with  a  large  team  of  data  scientists  to  review,  develop,  and  deploy  their
# research
#
# into
#
# production,
#
# ensuring
#
# its
#
# scalability
#
# and
#
# applicability
#
# to
#
# large
#
# datasets
#
# within
#
# a
#
# reasonable
#
# timeframe.
#  ●  Increased  data  delivery  frequency  to  production  from  once  a  month  to  daily.  ●  Implemented  and  automated  data  quality  checks,  regular  exports,  and  feature  validation.  ●  Refactored  legacy  solutions,  ensuring  seamless  integration  of  new  features  and
# reducing
#
# their
#
# implementation
#
# time
#
# from
#
# two
#
# years
#
# to
#
# one
#
# quarter.
#  ●  Optimized  team  workflows  and  processes  ●  Actively  participated  in  hiring,  onboarding,  and  knowledge-sharing  activities.   Key  Achievements:  Rebuilt  a  completely  disbanded  team  from  scratch.  Overhauled  all  legacy
# systems,
#
# improving
#
# data
#
# delivery
#
# processes,
#
# reducing
#
# errors
#
# and
#
# delays,
#
# and
#
# increasing
#
# calculation
#
# speed
#
# by
#
# 4x.
#
# Reduced
#
# infrastructure
#
# costs
#
# by
#
# 50%.
#
# Data  Engineer  —  Innotech  (12/2021  –  06/2022)
# ●  Developed  ETL  processes  to  automate  Asset-Liability  Management  (ALM)  in  VTB
# Treasury.
#
# ●  Contributed  to  the  development  of  a  cash  flow  calculator  for  the  bank's  risk  management  team,  similar  to  the  Kamakura  system.  ●  Implemented  code  quality  control  tools,  including  Pylint,  Bandit,  and  SonarQube.
# Key  Achievements:  Created  utility  tools  that  reduced  development  time,  code  complexity,  and  the  number  of  post-production  bugs  by  50%  when  adding  ETL  pipelines  for  new  data  sources.  Enforced  code  quality  standards  across  all  projects  using  SonarQube,  linters,  and  formatters.
# Data  Engineer  —  MTS,  Moscow  (06/2019  –  12/2021)
# ●  Maintained  daily  data  exports  and  processing,  optimizing  large-scale  data  workflows  with  Apache  Airflow.  ●  Developed  a  custom  ETL  engine  on  Spark,  enabling  seamless  data  transfers  between  sources  with  built-in  transformations  and  processing.  The  engine  supported  a  wide  range  of  data  sources,  including  file  storage,  relational  databases  (Oracle,  PostgreSQL,  MySQL,  Teradata,  ClickHouse),  Hadoop  (HDFS,  Hive),  FTP,  and  SFTP.  It  also  provided  the  capability  to  wrap  a  pipeline  into  an  Airflow  DAG  and  deploy  it  to  production  immediately.  ●  Integrated  data  lineage  tracking  across  all  pipelines  to  enhance  process  visibility.  ●  Enforced  code  quality  standards  across  all  projects  using  SonarQube,  linters,  and  formatters.
# Key  Achievements:  Accelerated  the  development,  testing,  and  production  deployment  of  data  pipelines  for  internal  product  teams  by  40%  through  the  creation  of  the  custom  ETL  engine  on  Spark.
# Skills  &  Technologies   Programming  Languages:  Python,  SQL  Data  Processing:  Pandas,  NumPy,  Scikit-Learn,  SciPy  Distributed  Systems:  Hadoop,  PySpark,  ClickHouse  Databases:  PostgreSQL,  MySQL  Orchestration  Tools:  Apache  Airflow,  Luigi  Cloud  &  DevOps:  Google  Cloud  Platform  (GCP),  AWS,  Linux,  Docker,  Prometheus,  Grafana,  Ansible,  Terraform,  Kubernetes  Skills:  Architecture  Design,  Team  Management,  Distributed  Systems,  Database  Optimization,  Big  Data,  Data  Engineering  Solutions  (DES),  Data  science,  ML,  LLM
# Education    National  Research  Nuclear  University  "MEPHI,"  Moscow  (2013  –  2019)  Faculty  of  Cybernetics  and  Information  Security,  Cryptology,  and  Cybersecurity.
# Languages    Russian  –  Native,  English  –  Professional  Working  Proficiency,  Japanese  –  Beginner

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Mark Vasilev"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# 'You are acting as Mark Vasilev. You are answering questions on Mark Vasilev\'s website, particularly questions related to Mark Vasilev\'s career, background, skills and experience. Your responsibility is to represent Mark Vasilev for interactions on the website as faithfully as possible. You are given a summary of Mark Vasilev\'s background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don\'t know the answer, say so.\n\n## Summary:\nMy name is Mark Vasilev. I\'m an software engineer and IT manager. I\'m originally from Moscow, Russia, but I moved to Tbilisi in 2022.\nI love travelling and travel a lot, I\'ve been in a lot of places around the glob. I learning japanese and spanish in the free time. Once I had my own Bar.\n\n## LinkedIn Profile:\n  \nMark  Vasilev  Data  Engineer   \nTelegram:  @Mark_Muffin  Cell/  WhatsApp:  +7  (910)  420-55-81  E-mail:  marok12@yandex.ru Tbilisi,  Georgia  \n Profile    Data  Engineer  with  seven  years  of  experience,  including  three  years  in  a  managerial  position  \nand\n \nteam\n \nleadership.\n \nExtensive\n \nexperience\n \nin\n \ndesigning\n \nand\n \nmaintaining\n \nvarious\n \nETL\n \npipelines,\n \noptimizing\n \ndata\n \nextraction\n \nprocesses,\n \nworking\n \nwith\n \nData\n \nQuality,\n \nand\n \nhandling\n \nlarge-scale\n \ndata.\n \nSuccessfully\n \ndeployed\n \nData\n \nScience\n \nprojects,\n \nincluding\n \nML\n \nand\n \nLLM\n \nmodels,\n \ninto\n \nproduction\n \nand\n \nensured\n \ntheir\n \nability\n \nto\n \nprocess\n \nlarge\n \nvolumes\n \nof\n \ndata\n \non\n \na\n \ndaily\n \nbasis.\n \nExpertise\n \nin\n \ndistributed\n \ndata\n \nstorage\n \nsystems\n \nand\n \nensuring\n \nhigh\n \ncode\n \nquality.\n \nStrong\n \nexperience\n \nin\n \nestablishing\n \nand\n \nstructuring\n \nteam\n \nworkflows.\n \nProven\n \nability\n \nto\n \ncommunicate\n \nwith\n \ncustomers,\n \ngather\n \nbusiness\n \nrequirements,\n \nand\n \ndefend\n \ntechnical\n \ndecisions\n \nin\n \nfront\n \nof\n \nstakeholders.\n \nExperienced\n \nin\n \nworking\n \nwithin\n \nmulticultural\n \nand\n \ncross-functional\n \nteams.\n  \nWork  Experience    Team  Lead  —  Semrush  (06/2022  –  Present)  \n●  Led  a  team  of  9  engineers  in  building  a  reliable  and  efficient  data  source  for  product  \nteams,\n \nenabling\n \nthem\n \nto\n \ndevelop\n \ntheir\n \nproducts\n \nbased\n \non\n \nhigh-quality\n \ndata.\n ●  Collaborated  with  a  large  team  of  data  scientists  to  review,  develop,  and  deploy  their  \nresearch\n \ninto\n \nproduction,\n \nensuring\n \nits\n \nscalability\n \nand\n \napplicability\n \nto\n \nlarge\n \ndatasets\n \nwithin\n \na\n \nreasonable\n \ntimeframe.\n ●  Increased  data  delivery  frequency  to  production  from  once  a  month  to  daily.  ●  Implemented  and  automated  data  quality  checks,  regular  exports,  and  feature  validation.  ●  Refactored  legacy  solutions,  ensuring  seamless  integration  of  new  features  and  \nreducing\n \ntheir\n \nimplementation\n \ntime\n \nfrom\n \ntwo\n \nyears\n \nto\n \none\n \nquarter.\n ●  Optimized  team  workflows  and  processes  ●  Actively  participated  in  hiring,  onboarding,  and  knowledge-sharing  activities.   Key  Achievements:  Rebuilt  a  completely  disbanded  team  from  scratch.  Overhauled  all  legacy  \nsystems,\n \nimproving\n \ndata\n \ndelivery\n \nprocesses,\n \nreducing\n \nerrors\n \nand\n \ndelays,\n \nand\n \nincreasing\n \ncalculation\n \nspeed\n \nby\n \n4x.\n \nReduced\n \ninfrastructure\n \ncosts\n \nby\n \n50%.\n \nData  Engineer  —  Innotech  (12/2021  –  06/2022)  \n●  Developed  ETL  processes  to  automate  Asset-Liability  Management  (ALM)  in  VTB  \nTreasury.\n \n●  Contributed  to  the  development  of  a  cash  flow  calculator  for  the  bank\'s  risk  management  team,  similar  to  the  Kamakura  system.  ●  Impl ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="openai/gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("OPENROUTER_API_KEY"), 
    base_url="https://openrouter.ai/api/v1"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="google/gemini-2.5-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'I do not currently hold any patents. My focus has primarily been on software engineering and data engineering, where I have implemented various projects and solutions, but I have not engaged in the patent process. If you have any specific questions related to my experience or projects, feel free to ask!'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback='The agent correctly states that it does not hold any patents, as this information is not present in its provided context.')

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="openai/gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Failed evaluation - retrying
# The agent's response is unacceptable. It uses 'pig Latin' which is unprofessional and not engaging. It completely deviates from the instructed persona. The response should be a professional and engaging statement about not having patents, as if speaking to a potential client or employer. Something like 'Thank you for asking! I actually don't hold any patents at this time.' would be more appropriate.
